# %%
import pandas as pd

# %%
a = pd.read_csv('data.csv')

# %%
b = pd.read_csv('data.csv')

# %%
b.plot()
# Out:
# <Axes: >

# %%
a['a'] += 1

# %%
a['b'] = a['a'] ** 2

# %%
a['c'] = a['b'] ** 2

# %%
# Plot a bar chart
a.plot(kind='bar')
# Out:
# <Axes: >
