# %%
import pandas as pd

# %%
a = pd.read_csv('data.csv')

# %%
b = pd.read_csv('data.csv')

# %%
b.plot()
# Out:
# <Axes: >

# %%
a['a'] += 1

# %%
a['b'] = a['a'] + 2

# %%
a.plot()
# Out:
# <Axes: >
